# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('logs/training_log.csv')
df
# Out:
#     epoch      loss       acc
# 0       1  3.254123  0.161226
# 1       2  2.391937  0.330659
# 2       3  1.890174  0.454489
# 3       4  1.676138  0.509440
# 4       5  1.552291  0.535614
# 5       6  1.458719  0.550246
# 6       7  1.393056  0.561275
# 7       8  1.342545  0.570824
# 8       9  1.298497  0.583132
# 9      10  1.255203  0.594362
# 10     11  1.216417  0.606918
# 11     12  1.179754  0.618342
# 12     13  1.149140  0.627434
# 13     14  1.119018  0.636044
# 14     15  1.088592  0.645407
# 15     16  1.063075  0.653770
# 16     17  1.037325  0.661536
# 17     18  1.013224  0.669666
# 18     19  0.991828  0.674828
# 19     20  0.969221  0.681958
# 20     21  0.948111  0.688081
# 21     22  0.927861  0.694956
# 22     23  0.910667  0.699870
# 23     24  0.890399  0.707186
# 24     25  0.873829  0.713611
# 25     26  0.855273  0.717735
# 26     27  0.839934  0.722796
# 27     28  0.822002  0.729043
# 28     29  0.806371  0.733716
# 29     30  0.788490  0.739134
# 30     31  0.775505  0.742397
# 31     32  0.762326  0.748194
# 32     33  0.748747  0.752457
# 33     34  0.732523  0.757285
# 34     35  0.718624  0.762494
# 35     36  0.705971  0.766532
# 36     37  0.689488  0.771670
# 37     38  0.673727  0.776786
# 38     39  0.663330  0.780568
# 39     40  0.649848  0.784474
# 40     41  0.638871  0.788039
# 41     42  0.624285  0.791039
# 42     43  0.609232  0.797270

# %%
sns.set()

# %%
plt.figure(figsize=(10, 8))
plt.plot(df['epoch'], df['loss'])
plt.title('Training Loss over Epochs')
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(df['epoch'], df['acc'])
plt.title('Training Accuracy over Epochs')
plt.show()
